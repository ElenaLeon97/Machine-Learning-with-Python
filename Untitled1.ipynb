# %%
import math as m
import numpy as np
import pandas as pd
import matplotlib as mat
import scipy as sp

# %%
a = np.array([1,2,3])

# %%
a
# Out:
# array([1, 2, 3])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
a.shape
# Out:
# (3,)

# %%
# Πούδιαστατος πίνακας
mdarray = np.array([[1,2,3],[4,5,6]])

# %%
mdarray
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
mdarray.shape
# Out:
# (2, 3)

# %%
from sc.special import exp20
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from sp.special import exp20
#
# ModuleNotFoundError: No module named 'sp'
