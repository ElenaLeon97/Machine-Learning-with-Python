# %%
list=[1,3,24,55,88]
print(list)
# Out:
# [1, 3, 24, 55, 88]

# %%
print(type(list))
# Out:
# <class 'list'>

# %%
list[0]
# Out:
# 1

# %%
list[1:3]
list[-2]
# Out:
# 55

# %%
string1='Hello World'

# %%
print(string1[0])
# Out:
# H

# %%
tulpe1=(1,4,8,16,24)

# %%
tulpe1
# Out:
# (1, 4, 8, 16, 24)

# %%
phone={
    'Alice':69450000, 'Oliver':60960000}

# %%
phone['Alice']
# Out:
# 69450000

# %%
phone.keys
# Out:
# <function dict.keys>

# %%
phone.keys()
# Out:
# dict_keys(['Alice', 'Oliver'])
